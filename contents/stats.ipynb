# %% [markdown]
# ---
# jupyter: python3
# title: Getting to know the data
# ---

# %%
import polars as pl
import numpy as np
from IPython.display import Markdown
from tabulate import tabulate

np.random.seed(1)

# %% [markdown]
# Let's start by reading in the data and printing some five random rows of it to get a sense for what we're dealing with.

# %%
# | column: page

df = pl.read_csv("../data/data.csv", separator=";", try_parse_dates=True)
df.sample(n=5)
# Out:
# shape: (5, 13)
# ┌───────┬──────────┬───────────────┬────────────┬───┬───────────────┬──────────────┬──────┬────────┐
# │ Rank  ┆ Mark     ┆ Competitor    ┆ DOB        ┆ … ┆ Mark [meters  ┆ Event        ┆ Wind ┆ Sex    │
# │ ---   ┆ ---      ┆ ---           ┆ ---        ┆   ┆ or seconds]   ┆ ---          ┆ ---  ┆ ---    │
# │ i64   ┆ str      ┆ str           ┆ date       ┆   ┆ ---           ┆ str          ┆ str  ┆ str    │
# │       ┆          ┆               ┆            ┆   ┆ f64           ┆              ┆      ┆        │
# ╞═══════╪══════════╪═══════════════╪════════════╪═══╪═══════════════╪══════════════╪══════╪════════╡
# │ 8277  ┆ 20.55    ┆ Rodney MARTIN ┆ 1982-12-22 ┆ … ┆ 20.5          ┆ 200 Metres   ┆ 1.2  ┆ male   │
# │ 10731 ┆ 10.2     ┆ Stanley FLOYD ┆ 1961-06-23 ┆ … ┆ 10.0          ┆ 100 Metres   ┆ 0.4  ┆ male   │
# │ 6152  ┆ 76.63    ┆ Aleksey       ┆ 1978-05-31 ┆ … ┆ 76.6          ┆ Hammer Throw ┆ null ┆ male   │
# │       ┆          ┆ ZAGORNIY      ┆            ┆   ┆               ┆              ┆      ┆        │
# │ 99    ┆ 4.83     ┆ Yelena        ┆ 1982-06-03 ┆ … ┆ 4.8           ┆ Pole Vault   ┆ null ┆ female │
# │       ┆          ┆ ISINBAYEVA    ┆            ┆   ┆               ┆              ┆      ┆        │
# │ 1260  ┆ 27:39.12 ┆ Brahim        ┆ 1967-08-15 ┆ … ┆ 1659.1        ┆ 10000 Metres ┆ null ┆ male   │
# │       ┆          ┆ BOUTAYEB      ┆            ┆   ┆               ┆              ┆      ┆        │
# └───────┴──────────┴───────────────┴────────────┴───┴───────────────┴──────────────┴──────┴────────┘

# %% [markdown]
# We can easily understand the different columns:
#
# - `Rank` is the rank of that performance for the given sex and event.
# - The `Mark` is the unparsed result entry for that performance. This can be in minutes, seconds, hours, meters (long jump) or points (decathlon).
# - `Competitor`, `DOB`, and `Nat` are the competitor's name, date of birth, and nationality.
# - `Pos` is the position that was achieved with this performance in that specific event where it was performed.
# - `Venue` and `Date` specify where and when the performance was achieved.
# - World Athletics assigns a score to a performance, that's what `Results Score` is.
# - `Mark [meters or seconds]` is my attempt to parse the `Mark` into seconds or meters, i.e. a `float`.
# - `Event` is the event name.
# - `Wind`, if available, tells the wind reading for that performance. This is mostly important for sprinting and jumping.
# - `Sex` is either female or male.

# %% [markdown]
# ## Some basic counts

# %% [markdown]
# Below are some basic counts of the data.

# %%
print("Shape of the dataframe:")
df.shape
# Out:
# Shape of the dataframe:
# (463847, 13)

# %%
print("Counts for male and female performance:")
df.groupby("Sex").count()
# Out:
# Counts for male and female performance:
# shape: (2, 2)
# ┌────────┬────────┐
# │ Sex    ┆ count  │
# │ ---    ┆ ---    │
# │ str    ┆ u32    │
# ╞════════╪════════╡
# │ male   ┆ 236187 │
# │ female ┆ 227660 │
# └────────┴────────┘

# %%
print("Performance count by sex and event, colored:")
(
    df.groupby("Sex", "Event")
    .count()
    .pivot(index="Event", columns="Sex", values="count", aggregate_function=None)
    .sort("female", descending=True)
    .to_pandas()
    .style.format(precision=0)
    .background_gradient(vmax=35_000)
    # .to_markdown()
)
# Out:
# Performance count by sex and event, colored:
# <style type="text/css">
# #T_a1e7f_row0_col1 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_a1e7f_row0_col2 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_a1e7f_row1_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_a1e7f_row1_col2 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_a1e7f_row2_col1 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_a1e7f_row2_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_a1e7f_row3_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_a1e7f_row3_col2 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_a1e7f_row4_col1 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_a1e7f_row4_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_a1e7f_row5_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_a1e7f_row5_col2, #T_a1e7f_row10_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_a1e7f_row6_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_a1e7f_row6_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_a1e7f_row7_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_a1e7f_row7_col2 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_a1e7f_row8_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_a1e7f_row8_col2 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_a1e7f_row9_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_a1e7f_row9_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_a1e7f_row10_col2, #T_a1e7f_row23_col2, #T_a1e7f_row43_col1, #T_a1e7f_row44_col1, #T_a1e7f_row45_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a1e7f_row11_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_a1e7f_row11_col2 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_a1e7f_row12_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_a1e7f_row12_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_a1e7f_row13_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_a1e7f_row13_col2 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_a1e7f_row14_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_a1e7f_row14_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_a1e7f_row15_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_a1e7f_row15_col2 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_a1e7f_row16_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a1e7f_row16_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_a1e7f_row17_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_a1e7f_row17_col2, #T_a1e7f_row20_col1, #T_a1e7f_row21_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a1e7f_row18_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_a1e7f_row18_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_a1e7f_row19_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_a1e7f_row19_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_a1e7f_row20_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_a1e7f_row21_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_a1e7f_row22_col1, #T_a1e7f_row28_col2, #T_a1e7f_row43_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a1e7f_row22_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_a1e7f_row23_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_a1e7f_row24_col1, #T_a1e7f_row38_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_a1e7f_row24_col2, #T_a1e7f_row26_col2, #T_a1e7f_row33_col1, #T_a1e7f_row34_col1, #T_a1e7f_row35_col1, #T_a1e7f_row35_col2, #T_a1e7f_row36_col1, #T_a1e7f_row36_col2, #T_a1e7f_row37_col1, #T_a1e7f_row37_col2, #T_a1e7f_row38_col1, #T_a1e7f_row39_col1, #T_a1e7f_row40_col1, #T_a1e7f_row41_col1, #T_a1e7f_row41_col2, #T_a1e7f_row42_col1, #T_a1e7f_row44_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a1e7f_row25_col1, #T_a1e7f_row26_col1, #T_a1e7f_row27_col1, #T_a1e7f_row28_col1, #T_a1e7f_row29_col1, #T_a1e7f_row30_col1, #T_a1e7f_row30_col2, #T_a1e7f_row32_col2, #T_a1e7f_row34_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a1e7f_row25_col2, #T_a1e7f_row31_col1, #T_a1e7f_row32_col1, #T_a1e7f_row33_col2, #T_a1e7f_row39_col2, #T_a1e7f_row40_col2, #T_a1e7f_row42_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_a1e7f_row27_col2, #T_a1e7f_row29_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_a1e7f_row31_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_a1e7f_row45_col2 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# </style>
# <table id="T_a1e7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1e7f_level0_col0" class="col_heading level0 col0" >Event</th>
#       <th id="T_a1e7f_level0_col1" class="col_heading level0 col1" >female</th>
#       <th id="T_a1e7f_level0_col2" class="col_heading level0 col2" >male</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1e7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1e7f_row0_col0" class="data row0 col0" >Hammer Throw</td>
#       <td id="T_a1e7f_row0_col1" class="data row0 col1" >33647</td>
#       <td id="T_a1e7f_row0_col2" class="data row0 col2" >12984</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1e7f_row1_col0" class="data row1 col0" >100 Metres</td>
#       <td id="T_a1e7f_row1_col1" class="data row1 col1" >26983</td>
#       <td id="T_a1e7f_row1_col2" class="data row1 col2" >24875</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1e7f_row2_col0" class="data row2 col0" >200 Metres</td>
#       <td id="T_a1e7f_row2_col1" class="data row2 col1" >22067</td>
#       <td id="T_a1e7f_row2_col2" class="data row2 col2" >15005</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1e7f_row3_col0" class="data row3 col0" >Pole Vault</td>
#       <td id="T_a1e7f_row3_col1" class="data row3 col1" >15670</td>
#       <td id="T_a1e7f_row3_col2" class="data row3 col2" >16388</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1e7f_row4_col0" class="data row4 col0" >3000 Metres Steeplechase</td>
#       <td id="T_a1e7f_row4_col1" class="data row4 col1" >15125</td>
#       <td id="T_a1e7f_row4_col2" class="data row4 col2" >9665</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1e7f_row5_col0" class="data row5 col0" >Javelin Throw</td>
#       <td id="T_a1e7f_row5_col1" class="data row5 col1" >13449</td>
#       <td id="T_a1e7f_row5_col2" class="data row5 col2" >7564</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1e7f_row6_col0" class="data row6 col0" >800 Metres</td>
#       <td id="T_a1e7f_row6_col1" class="data row6 col1" >11597</td>
#       <td id="T_a1e7f_row6_col2" class="data row6 col2" >7283</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1e7f_row7_col0" class="data row7 col0" >400 Metres</td>
#       <td id="T_a1e7f_row7_col1" class="data row7 col1" >10867</td>
#       <td id="T_a1e7f_row7_col2" class="data row7 col2" >8189</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1e7f_row8_col0" class="data row8 col0" >1500 Metres</td>
#       <td id="T_a1e7f_row8_col1" class="data row8 col1" >9456</td>
#       <td id="T_a1e7f_row8_col2" class="data row8 col2" >9107</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1e7f_row9_col0" class="data row9 col0" >20 Kilometres Race Walk</td>
#       <td id="T_a1e7f_row9_col1" class="data row9 col1" >9275</td>
#       <td id="T_a1e7f_row9_col2" class="data row9 col2" >3773</td>
#     </tr>
#     <tr>
#       <th id="T_a1e7f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td i

# %%
import altair as alt
from camminapy.plot import altair_theme

print("Count of performances grouped by year (starting 1960):")

altair_theme()
alt.Chart(
    df.with_columns(pl.col("Date").dt.year())
    .groupby("Date", "Sex")
    .count()
    .filter(pl.col("Date") > 1960)
    .sort("Date")
    .to_pandas()
).mark_bar(clip=True).encode(
    x=alt.X("Date:N").axis(labelAngle=-90, values=list(range(1960, 2024, 2))),
    y="count:Q",
    color=alt.Color("Sex:N").scale(
        domain=["female", "male"], range=["purple", "green"]
    ),
).properties(
    height=300, width=550
)
# Out:
# Count of performances grouped by year (starting 1960):
# alt.Chart(...)

# %% [markdown]
# Interesting to see COVID pop up in this data as well.

# %%
print("The top 10 events with the most performances:")
(
    df.groupby("Event")
    .count()
    .sort("count", descending=True)
    .head(10)
    .to_pandas()
    .style.background_gradient(subset="count")
)
# Out:
# The top 10 events with the most performances:
# <style type="text/css">
# #T_0c0bf_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0c0bf_row1_col1 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_0c0bf_row2_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_0c0bf_row3_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_0c0bf_row4_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_0c0bf_row5_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_0c0bf_row6_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_0c0bf_row7_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_0c0bf_row8_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_0c0bf_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_0c0bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c0bf_level0_col0" class="col_heading level0 col0" >Event</th>
#       <th id="T_0c0bf_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c0bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c0bf_row0_col0" class="data row0 col0" >100 Metres</td>
#       <td id="T_0c0bf_row0_col1" class="data row0 col1" >51858</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c0bf_row1_col0" class="data row1 col0" >Hammer Throw</td>
#       <td id="T_0c0bf_row1_col1" class="data row1 col1" >46631</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c0bf_row2_col0" class="data row2 col0" >200 Metres</td>
#       <td id="T_0c0bf_row2_col1" class="data row2 col1" >37072</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c0bf_row3_col0" class="data row3 col0" >Pole Vault</td>
#       <td id="T_0c0bf_row3_col1" class="data row3 col1" >32058</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c0bf_row4_col0" class="data row4 col0" >3000 Metres Steeplechase</td>
#       <td id="T_0c0bf_row4_col1" class="data row4 col1" >24790</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c0bf_row5_col0" class="data row5 col0" >Shot Put</td>
#       <td id="T_0c0bf_row5_col1" class="data row5 col1" >23407</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c0bf_row6_col0" class="data row6 col0" >400 Metres Hurdles</td>
#       <td id="T_0c0bf_row6_col1" class="data row6 col1" >22480</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c0bf_row7_col0" class="data row7 col0" >Javelin Throw</td>
#       <td id="T_0c0bf_row7_col1" class="data row7 col1" >21013</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c0bf_row8_col0" class="data row8 col0" >400 Metres</td>
#       <td id="T_0c0bf_row8_col1" class="data row8 col1" >19056</td>
#     </tr>
#     <tr>
#       <th id="T_0c0bf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c0bf_row9_col0" class="data row9 col0" >800 Metres</td>
#       <td id="T_0c0bf_row9_col1" class="data row9 col1" >18880</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(
    "Let's finish with an overview that shows during which months, which events are held:"
)
alt.Chart(
    df.with_columns(pl.col("Date").dt.month())
    .groupby("Date", "Sex", "Event")
    .count()
    .filter(pl.col("Event").str.contains("Walk").is_not())
    .sort("Date")
    .to_pandas()
).mark_bar(clip=True).encode(
    x=alt.X("Date:N").title("Month of Year"),
    y="count:Q",
    color=alt.Color("Sex:N").scale(
        domain=["female", "male"], range=["purple", "green"]
    ),
    row="Event:N",
).properties(
    height=200, width=550
).resolve_scale(
    y="independent"
)
# Out:
# alt.Chart(...)
